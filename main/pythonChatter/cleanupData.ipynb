# %% [markdown]
# # Clean up numbers

# %%
outFile = open('../data/shittalkCleaned.txt', 'w')
inFile = open('../data/shittalk.txt')
for line in inFile:
    outFile.write( line.split("|")[1] )

# %% [markdown]
# # Convert into CSV

# %%
import pandas as pd

# %%
#error_bad_lines=False => somehow some lines can't be read
dataOnlyText = pd.read_table('../data/shittalkCleaned.txt', error_bad_lines=False)
dataOnlyText['Rating'] = 'none'
dataOnlyText['keywords'] = ''
dataOnlyText['count'] = 0
dataOnlyText.to_csv('../data/ShitTalkTable.csv')
# Out:
# Skipping line 49: expected 1 fields, saw 2
# Skipping line 296: expected 1 fields, saw 2
# Skipping line 556: expected 1 fields, saw 2

# %% [markdown]
# # Keyword extraction

# %%
import nltk
dataTable = pd.read_csv('../data/ShitTalkTable.csv')

# %%
textTest = dataTable['Text'][0]

# %% [markdown]
# # Delete bad jokes

# %%
import insulterFromDatabase as ai
import pandas as pd
pd.options.display.max_colwidth = 100
dataTable = pd.read_csv('../../data/ShitTalkTable.csv')

# %%
# re-do the dict assignment after deletion
keyDict = ai.putKeywordsToDict( dataTable )
len( keyDict )
# Out:
# 589

# %%
filterWord = 'aim'
# dataTable = dataTable.drop( dataTable.index[ keyDict[ filterWord ] ] )
dataTable.to_csv('../../data/ShitTalkTable_Filtered.csv')
# dataTable = pd.read_csv('../../data/ShitTalkTable_Filtered.csv')
keyDict = ai.putKeywordsToDict( dataTable ) # re-do the dict assignment after deletion
print( len(dataTable.index))
print( len( keyDict ) )
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-19-c5de912e4dc3> in <module>()
#       3 dataTable.to_csv('../../data/ShitTalkTable_Filtered.csv')
#       4 dataTable = pd.read_csv('../../data/ShitTalkTable_Filtered.csv')
# ----> 5 keyDict = ai.putKeywordsToDict( dataTable ) # re-do the dict assignment after deletion
#       6 print( len(dataTable.index))
#       7 print( len( keyDict ) )
#
# /Users/sonneundasche/programming/of/apps/ElisaKora/main/pythonChatter/insulterFromDatabase.pyc in putKeywordsToDict(dataFrame)
#      65     for index, row_ in dataFrame.iterrows():
#      66         text_ = row_[ 1 ]
# ---> 67         keywords_ = getKeywords( text_ )
#      68         for _key in keywords_:
#      69             dict_[ _key ].append( index )
#
# /Users/sonneundasche/programming/of/apps/ElisaKora/main/pythonChatter/insulterFromDatabase.pyc in getKeywords(textIn)
#      53 # -----------------------------------
#      54 def getKeywords( textIn ):
# ---> 55     tokens_ = tokenizer.tokenize( textIn )
#      56     tagged_ = nltk.pos_tag( tokens_ )
#      57     result = [ word for word,pos in tagged_ if pos == 'NN']
#
# /Users/sonneundasche/programming/PythonVirEnv/SkipThoughtVector/lib/python2.7/site-packages/nltk/tokenize/regexp.pyc in tokenize(self, text)
#     127         # If our regexp matches tokens, use re.findall:
#     128         else:
# --> 129             return self._regexp.findall(text)
#     130
#     131     def span_tokenize(self, text):
#
# TypeError: expected string or buffer

# %%
filterWord = 'turn'
                      
for rowNr in keyDict[ filterWord ] :
    dataTable.set_value( rowNr, 'Rating', 'shit')
    # print dataTable.iloc[ rowNr ]
    
print len( keyDict[ filterWord ] ) 
dataTable[ dataTable.Rating == 'shit' ].Rating.count()
# Out:
# 2
# 214

# %%
keyDictFiltered = ai.putKeywordsToDict( dataTable[ dataTable.Rating != 'shit' ] )
# pair = keyDictFiltered[ 'amount' ]
# pair
for k in keyDictFiltered :
   length = len( keyDictFiltered[ k ] )
   if length > 1 :
       print str(length) + " " + str(k)
# Out:
# 2 dollar
# 3 shot
# 2 sniper
# 2 fan
# 2 school
# 4 level
# 2 die
# 7 button
# 2 list
# 2 crosshair
# 5 guy
# 2 round
# 2 existance
# 3 jump
# 3 video
# 2 perspective
# 2 cactus
# 2 wait
# 4 coffin
# 3 amount
# 3 gene
# 4 family
# 2 excuse
# 3 everybody
# 2 use
# 2 insult
# 2 type
# 2 today
# 3 phone
# 2 shoot
# 2 soup
# 2 example
# 2 control
# 5 salty
# 15 something
# 2 sense
# 2 turn
# 4 map
# 3 sandwich
# 5 lag
# 3 man
# 2 Everyone
# 2 talk
# 2 refund
# 3 sperm
# 6 brain
# 3 existence
# 2 bunch
# 5 monitor
# 2 policy
# 6 dad
# 4 someone
# 4 day
# 2 didn
# 3 mode
# 2 everyone
# 2 idea
# 11 thing
# 3 internet
# 3 cause
# 3 highway
# 8 ass
# 3 difficulty
# 11 reason
# 3 hand
# 3 place
# 2 router
# 2 number
# 2 system
# 2 option
# 2 tree
# 2 mind
# 2 argument
# 5 ego
# 2 asshole
# 2 prick
# 9 mouth
# 9 don
# 5 face
# 2 Earth
# 7 salt
# 2 selection
# 2 hunger
# 2 crayon
# 2 ground
# 3 dick
# 3 condom
# 5 awareness
# 2 enemy
# 5 evolution
# 6 computer
# 6 screen
# 3 coma
# 9 joke
# 3 job
# 3 s
# 2 point
# 2 wall
# 10 life
# 4 fire
# 2 look
# 3 value
# 3 cock
# 2 layer
# 2 im
# 9 mouse
# 13 shit
# 2 retard
# 7 i
# 7 person
# 7 mother
# 3 sentence
# 3 skill
# 2 coordination
# 2 generator
# 2 character
# 4 mom
# 5 world
# 3 trash
# 24 t
# 2 right
# 7 fucking
# 6 tutorial
# 2 participation
# 3 power
# 2 eye
# 2 sister
# 2 garbage
# 6 support
# 2 grave
# 5 head
# 3 count
# 3 dog
# 9 chromosome
# 3 vocabulary
# 2 handicap
# 4 chance
# 3 pool
# 2 potato
# 23 time

# %%
dataTable.to_csv('../../data/ShitTalkTable_Filtered.csv')

# %%
filterWord = 'turn'
for rowNr in keyDictFiltered[ filterWord ] :
    print dataTable.loc[ rowNr ].Text
# Out:
# why turn on the computer if you're just gonna make it depressed
# You know this isn't turn based combat right? When they shoot at you feel free to shoot back.

# %%
import insulterFromDatabase as ai
import pandas as pd
pd.options.display.max_colwidth = 100
dataTableShitTalk = pd.read_csv( '../../data/ShitTalkTable_Filtered.csv' )
dataTableShitTalk = dataTableShitTalk[ dataTableShitTalk.Rating != 'shit' ]

# %%
dataTableShitTalk.drop(dataTableShitTalk.columns[[0]], axis=1, inplace=True)
# dataTableShitTalk

# %%
dataTableShitTalk
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0.1</th>
#       <th>Text</th>
#       <th>Rating</th>
#       <th>keywords</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Team Fortress 2 is also Free-To-Uninstall</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>If the body is 70% water how are you 100% salt???</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>You're the reason the gene pool needs a lifeguard.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>I'm jealous of people that don't know you.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>I have neither the time, nor the crayons, to explain this to you.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>I would insult you but nature did a better job.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>Your birth certificate is an apology letter from the condom factory.</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>Don't worry guys, I'm a garbage collector. I'm used to carrying trash.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>I'm not questioning your intelligence, merely denying its existence</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>Perhaps your strategy should include trying.</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>10</td>
#       <td>Some people get paid to suck, you do it for free.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>11</td>
#       <td>I'd tell you to commit suicide, but then you'd have a kill.</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>12</td>
#       <td>You have worse map awareness than Christopher fucking Columbus.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>13</td>
#       <td>You must really like that respawn timer</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>14</td>
#       <td>You're the human equivalent of a participation award.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>15</td>
#       <td>You have the situational awareness of a potato</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>16</td>
#       <td>I'd tell you to go outside, but you'd just ruin that for everyone else too</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>17</td>
#       <td>With aim like that, I pity whoever has to clean the floor around your toilet</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>18</td>
#       <td>At least your ping score is higher than mine.</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>19</td>
#       <td>if i wanted to kill myself id jump from your ego to your IQ</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>20</td>
#       <td>You have the situational awareness of a potato</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>21</td>
#       <td>I hope one day you regain the use of your hands.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>22</td>
#       <td>Are you aiming for a pacifist walkthrough?</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>23</td>
#       <td>Your kills are like all Valve franchises, stuck at 2</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>24</td>
#       <td>The keys you're looking for are Alt-F4</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>25</td>
#       <td>You know all those times your parents said video games would get you nowhere? They were right.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>26</td>
#       <td>I'd love to see things from your perspective, but I don't think I could shove my head that far u...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>27</td>
#       <td>**PROTIP** Your crosshair generally assists you in aiming.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>28</td>
#       <td>Does your ass get jealous of all the shit that comes out of your mouth?</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>29</td>
#       <td>Everyone who loves you is wrong.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>686</th>
#       <td>686</td>
#       <td>If you're going to be two-faced, at least make one of them pretty.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>687</th>
#       <td>687</td>
#       <td>I'd say your aim is cancer, but cancer actually kills people.</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>688</th>
#       <td>688</td>
#       <td>I'm not saying you're useless, but I'd unplug your router to charge my phone.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>689</th>
#       <td>689</td>
#       <td>Stephen Hawking did great with his disability. Why can't you?</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>690</th>
#       <td>690</td>
#       <td>I'm pretty sure you've typed more sentences than landed shots.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>691</th>
#       <td>691</td>
#       <td>I'd call you aim cancer but, cancer kills.</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>692</th>
#       <td>692</td>
#       <td>With an aim like that, I'm surprised you were able to turn your PC on.</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>693</th>
#       <td>693</td>
#       <td>Dropped Like A Newborn Baby</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>694</th>
#       <td>694</td>
#       <td>Just fucking throw your mouse at your screen, that'll be the first shot you hit. You know what? ...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>695</th>
#       <td>695</td>
#       <td>You don't seem to have much skill. You know, you can always go play Overwatch.</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>696</th>
#       <td>696</td>
#       <td>Why don't you slip into something more comfortable -- like a coma</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>697</th>
#       <td>697</td>
#       <td>Could you imagine what it would have been like if you had more oxygen at birth</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>698</th>
#       <td>698</td>
#       <td>I would call you cancer, but cancer actually kills people.</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>699</th>
#       <td>699</td>
#       <td>I see, the reason you don't push the payload is that even it can't carry you if you sit on it.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>700</th>
#       <td>700</td>
#       <td>It's a joke, not a cock. Stop taking it hard.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>701</th>
#       <td>701</td>
#       <td>just because it's on the scoreboard, it doesn't mean dying gets you points</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>702</th>
#       <td>702</td>
#       <td>Do people find your Tinder profile using the 'Sort by highest Chromosome count' option?</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>703</th>
#       <td>703</td>
#       <td>I sometimes contemplate suicide, but then who would be around to tell you how terrible you are.</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>704</th>
#       <td>704</td>
#       <td>I've seen better reflexes from Polio sufferers.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>705</th>
#       <td>705</td>
#       <td>Team Fortress  is also Free-To-Uninstall</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>706</th>
#       <td>706</td>
#       <td>What's the similarity between your mom and you? Both you and your mom suck.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>707</th>
#       <td>707</td>
#       <td>I think you need more practice with your aim. You can try using the broadside of a barn as a tra...</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>708</th>
#       <td>708</td>
#       <td>Weird, I didn't know they let bots run loose in public games?</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>709</th>
#       <td>709</td>
#       <td>What are you doing here? The nearest elementary school is at lest 10km away.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>710</th>
#       <td>710</td>
#       <td>You should try your luck at russian roulette, at least you might kill something</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>711</th>
#       <td>711</td>
#       <td>If ugliness was measured in bricks, you would make the great wall of china.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>712</th>
#       <td>712</td>
#       <td>Your mother is so ugly people break into your house just to close the curtains</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>713</th>
#       <td>713</td>
#       <td>your birth certificate was an apology letter from the condom company</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>714</th>
#       <td>714</td>
#       <td>Maybe if you spent as much effort on the game as do bitching, you might actually kill something ...</td>
#       <td>shit</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>715</th>
#       <td>715</td>
#       <td>The Earth</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# <p>716 rows × 5 columns</p>
# </div>
