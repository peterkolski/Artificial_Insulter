# %% [markdown]
# # Clean up numbers

# %%
outFile = open('../data/shittalkCleaned.txt', 'w')
inFile = open('../data/shittalk.txt')
for line in inFile:
    outFile.write( line.split("|")[1] )

# %% [markdown]
# # Convert into CSV

# %%
import pandas as pd

# %%
#error_bad_lines=False => somehow some lines can't be read
dataOnlyText = pd.read_table('../data/shittalkCleaned.txt', error_bad_lines=False)
dataOnlyText['Rating'] = 'none'
dataOnlyText['keywords'] = ''
dataOnlyText['count'] = 0
dataOnlyText.to_csv('../data/ShitTalkTable.csv')
# Out:
# Skipping line 49: expected 1 fields, saw 2
# Skipping line 296: expected 1 fields, saw 2
# Skipping line 556: expected 1 fields, saw 2

# %% [markdown]
# # Keyword extraction

# %%
import nltk
dataTable = pd.read_csv('../data/ShitTalkTable.csv')

# %%
textTest = dataTable['Text'][0]

# %% [markdown]
# # Delete bad jokes

# %%
import insulterFromDatabase as ai
import pandas as pd
pd.options.display.max_colwidth = 100
dataTable = pd.read_csv('../../data/ShitTalkTable.csv')

# %%
# re-do the dict assignment after deletion
keyDict = ai.putKeywordsToDict( dataTable )
len( keyDict )
# Out:
# 589

# %%
filterWord = 'aim'
dataTable = dataTable.drop( dataTable.index[ keyDict[ filterWord ] ] )
dataTable.to_csv('../../data/ShitTalkTable_Filtered.csv')
dataTable = pd.read_csv('../../data/ShitTalkTable_Filtered.csv')
keyDict = ai.putKeywordsToDict( dataTable ) # re-do the dict assignment after deletion
print( len(dataTable.index))
print( len( keyDict ) )
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-19-c5de912e4dc3> in <module>()
#       3 dataTable.to_csv('../../data/ShitTalkTable_Filtered.csv')
#       4 dataTable = pd.read_csv('../../data/ShitTalkTable_Filtered.csv')
# ----> 5 keyDict = ai.putKeywordsToDict( dataTable ) # re-do the dict assignment after deletion
#       6 print( len(dataTable.index))
#       7 print( len( keyDict ) )
#
# /Users/sonneundasche/programming/of/apps/ElisaKora/main/pythonChatter/insulterFromDatabase.pyc in putKeywordsToDict(dataFrame)
#      65     for index, row_ in dataFrame.iterrows():
#      66         text_ = row_[ 1 ]
# ---> 67         keywords_ = getKeywords( text_ )
#      68         for _key in keywords_:
#      69             dict_[ _key ].append( index )
#
# /Users/sonneundasche/programming/of/apps/ElisaKora/main/pythonChatter/insulterFromDatabase.pyc in getKeywords(textIn)
#      53 # -----------------------------------
#      54 def getKeywords( textIn ):
# ---> 55     tokens_ = tokenizer.tokenize( textIn )
#      56     tagged_ = nltk.pos_tag( tokens_ )
#      57     result = [ word for word,pos in tagged_ if pos == 'NN']
#
# /Users/sonneundasche/programming/PythonVirEnv/SkipThoughtVector/lib/python2.7/site-packages/nltk/tokenize/regexp.pyc in tokenize(self, text)
#     127         # If our regexp matches tokens, use re.findall:
#     128         else:
# --> 129             return self._regexp.findall(text)
#     130
#     131     def span_tokenize(self, text):
#
# TypeError: expected string or buffer

# %%
dataTable
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>Text</th>
#       <th>Rating</th>
#       <th>keywords</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Team Fortress 2 is also Free-To-Uninstall</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>If the body is 70% water how are you 100% salt???</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>You're the reason the gene pool needs a lifegu...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>I'm jealous of people that don't know you.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>I have neither the time, nor the crayons, to e...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>I would insult you but nature did a better job.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>Your birth certificate is an apology letter fr...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>Don't worry guys, I'm a garbage collector. I'm...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>I'm not questioning your intelligence, merely ...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>Perhaps your strategy should include trying.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>10</td>
#       <td>Some people get paid to suck, you do it for fr...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>11</td>
#       <td>I'd tell you to commit suicide, but then you'd...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>12</td>
#       <td>You have worse map awareness than Christopher ...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>13</td>
#       <td>You must really like that respawn timer</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>14</td>
#       <td>You're the human equivalent of a participation...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>15</td>
#       <td>You have the situational awareness of a potato</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>16</td>
#       <td>I'd tell you to go outside, but you'd just rui...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>18</td>
#       <td>At least your ping score is higher than mine.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>19</td>
#       <td>if i wanted to kill myself id jump from your e...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>20</td>
#       <td>You have the situational awareness of a potato</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>21</td>
#       <td>I hope one day you regain the use of your hands.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>22</td>
#       <td>Are you aiming for a pacifist walkthrough?</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>23</td>
#       <td>Your kills are like all Valve franchises, stuc...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>24</td>
#       <td>The keys you're looking for are Alt-F4</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>25</td>
#       <td>You know all those times your parents said vid...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>26</td>
#       <td>I'd love to see things from your perspective, ...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>27</td>
#       <td>**PROTIP** Your crosshair generally assists yo...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>28</td>
#       <td>Does your ass get jealous of all the shit that...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>29</td>
#       <td>Everyone who loves you is wrong.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>30</td>
#       <td>have you ever had a conversation where the oth...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>682</th>
#       <td>682</td>
#       <td>You're the reason why no religion has a god th...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>683</th>
#       <td>683</td>
#       <td>If laughter is the best medicine, your face mu...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>684</th>
#       <td>684</td>
#       <td>I'd say you're cancer, but at least cancer kills.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>685</th>
#       <td>685</td>
#       <td>Why don't you slip into something more comfort...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>686</th>
#       <td>686</td>
#       <td>If you're going to be two-faced, at least make...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>688</th>
#       <td>688</td>
#       <td>I'm not saying you're useless, but I'd unplug ...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>689</th>
#       <td>689</td>
#       <td>Stephen Hawking did great with his disability....</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>690</th>
#       <td>690</td>
#       <td>I'm pretty sure you've typed more sentences th...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>691</th>
#       <td>691</td>
#       <td>I'd call you aim cancer but, cancer kills.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>693</th>
#       <td>693</td>
#       <td>Dropped Like A Newborn Baby</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>694</th>
#       <td>694</td>
#       <td>Just fucking throw your mouse at your screen, ...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>695</th>
#       <td>695</td>
#       <td>You don't seem to have much skill. You know, y...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>696</th>
#       <td>696</td>
#       <td>Why don't you slip into something more comfor...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>698</th>
#       <td>698</td>
#       <td>I would call you cancer, but cancer actually k...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>699</th>
#       <td>699</td>
#       <td>I see, the reason you don't push the payload i...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>700</th>
#       <td>700</td>
#       <td>It's a joke, not a cock. Stop taking it hard.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>701</th>
#       <td>701</td>
#       <td>just because it's on the scoreboard, it doesn'...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>702</th>
#       <td>702</td>
#       <td>Do people find your Tinder profile using the '...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>703</th>
#       <td>703</td>
#       <td>I sometimes contemplate suicide, but then who ...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>704</th>
#       <td>704</td>
#       <td>I've seen better reflexes from Polio sufferers.</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>705</th>
#       <td>705</td>
#       <td>Team Fortress  is also Free-To-Uninstall</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>706</th>
#       <td>706</td>
#       <td>What's the similarity between your mom and you...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>708</th>
#       <td>708</td>
#       <td>Weird, I didn't know they let bots run loose i...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>709</th>
#       <td>709</td>
#       <td>What are you doing here? The nearest elementar...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>710</th>
#       <td>710</td>
#       <td>You should try your luck at russian roulette, ...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>711</th>
#       <td>711</td>
#       <td>If ugliness was measured in bricks, you would ...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>712</th>
#       <td>712</td>
#       <td>Your mother is so ugly people break into your ...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>713</th>
#       <td>713</td>
#       <td>your birth certificate was an apology letter f...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>714</th>
#       <td>714</td>
#       <td>Maybe if you spent as much effort on the game ...</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>715</th>
#       <td>715</td>
#       <td>The Earth</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# <p>667 rows × 5 columns</p>
# </div>

# %%
keyDict
# Out:
# defaultdict(list,
#             {'Achievement': [153],
#              'Earth': [682, 715],
#              'Everyone': [29, 267],
#              'GPA': [330],
#              'Help': [84],
#              'IQ': [604],
#              'Imagine': [442, 468, 511, 598, 632, 633],
#              'Investment': [452],
#              'Iridium': [635, 635],
#              'Kill': [374],
#              'PC': [692],
#              'Play': [309],
#              'Sort': [702],
#              'Steam': [73],
#              'Stormtrooper': [317],
#              'Strike': [436],
#              'Team': [178, 561, 705],
#              'Tinder': [560],
#              'Trying': [418],
#              'Twitch': [118],
#              'abacus': [282],
#              'ability': [325, 393],
#              'abortion': [121, 353, 439, 510, 516, 526, 577, 678],
#              'abuse': [578],
#              'accident': [173],
#              'accuracy': [626],
#              'addiction': [588],
#              'advantage': [406],
#              'advertisment': [531],
#              'advice': [284],
#              'age': [544],
#              'aim': [17,
#               35,
#               188,
#               223,
#               266,
#               289,
#               296,
#               331,
#               359,
#               373,
#               414,
#               421,
#               437,
#               451,
#               454,
#               524,
#               530,
#               595,
#               687,
#               692,
#               707],
#              'aimbot': [613],
#              'alive': [548],
#              'alphabet': [163],
#              'alt': [305],
#              'ammo': [338],
#              'amount': [49, 110, 174],
#              'animal': [366],
#              'anybody': [329],
#              'anyone': [140],
#              'anything': [543, 622],
#              'apology': [31, 388, 549],
#              'argue': [327],
#              'argument': [78, 589],
#              'aspiration': [630],
#              'ass': [26, 28, 49, 110, 174, 200, 505, 512, 562, 646],
#              'asshole': [146, 222],
#              'athiest': [583],
#              'attention': [120],
#              'award': [14],
#              'awareness': [12, 15, 20, 68, 541],
#              'aww': [140],
#              'back': [499],
#              'ban': [484],
#              'bar': [591],
#              'bark': [324],
#              'barn': [707],
#              'batch': [407],
#              'bear': [102],
#              'beat': [369],
#              'beaten': [407],
#              'becuase': [256],
#              'bed': [71],
#              'bench': [157, 157, 571],
#              'birth': [6,
#               31,
#               388,
#               399,
#               442,
#               468,
#               494,
#               511,
#               515,
#               549,
#               598,
#               607,
#               632,
#               633,
#               654,
#               659,
#               697,
#               713],
#              'bit': [408],
#              'bitch': [366, 512, 646],
#              'blank': [341],
#              'bleach': [446],
#              'blind': [316],
#              'blindfold': [309],
#              'blindness': [296],
#              'block': [100],
#              'blood': [311, 336],
#              'boat': [331, 447],
#              'body': [1, 113, 478],
#              'bodypillow': [427],
#              'bongos': [663],
#              'boot': [150, 575, 584, 594, 610],
#              'booze': [678],
#              'bot': [104, 187],
#              'bottom': [154, 168],
#              'bowl': [163],
#              'box': [60],
#              'brain': [122, 181, 184, 311, 336, 502, 533, 670],
#              'break': [116],
#              'breast': [46],
#              'breath': [627],
#              'broadside': [707],
#              'bucket': [46],
#              'buddy': [630],
#              'building': [681],
#              'bullet': [558],
#              'bunch': [360, 483],
#              'burst': [299],
#              'button': [142, 224, 239, 244, 272, 277, 315, 368, 451, 573],
#              'cable': [291],
#              'cactus': [220, 401],
#              'cam': [400],
#              'cancer': [170,
#               421,
#               421,
#               423,
#               423,
#               435,
#               435,
#               493,
#               504,
#               504,
#               520,
#               524,
#               524,
#               528,
#               530,
#               530,
#               532,
#               532,
#               542,
#               551,
#               551,
#               559,
#               559,
#               570,
#               570,
#               587,
#               587,
#               597,
#               597,
#               609,
#               616,
#               616,
#               629,
#               636,
#               636,
#               680,
#               684,
#               684,
#               687,
#               687,
#               691,
#               691,
#               698,
#               698],
#              'card': [73],
#              'care': [534],
#              'caretaker': [479],
#              'carry': [85],
#              'carrying': [525],
#              'cart': [632],
#              'casket': [617],
#              'cause': [89, 126, 199, 492],
#              'ceiling': [99],
#              'centipede': [98],
#              'centre': [637],
#              'certificate': [6, 31, 388, 515, 549, 713],
#              'chair': [42, 167],
#              'challenge': [94],
#              'chance': [47, 316, 438, 605, 677],
#              'character': [300, 573],
#              'charity': [223],
#              'cheat': [257],
#              'child': [442, 468, 494, 511, 552, 633],
#              'china': [711],
#              'choice': [547],
#              'chromosome': [85, 183, 191, 328, 402, 429, 489, 495, 521, 670],
#              'church': [342],
#              'cigarette': [528],
#              'city': [109],
#              'class': [56],
#              'clay': [360],
#              'client': [295],
#              'clinic': [121],
#              'club': [123],
#              'coat': [467],
#              'cock': [51, 176, 700],
#              'coffin': [65, 430, 462, 538],
#              'cold': [359],
#              'collector': [7, 109],
#              'coma': [377, 685, 696],
#              'combat': [335],
#              'comeback': [66],
#              'company': [549, 713],
#              'comparison': [667],
#              'competition': [527],
#              'complex': [464],
#              'compliment': [667],
#              'computer': [125, 127, 206, 213, 272, 315],
#              'concept': [419],
#              'concert': [223],
#              'condom': [6, 31, 158, 388, 467, 531, 549, 713],
#              'connection': [345],
#              'contest': [618],
#              'contradiction': [449],
#              'control': [77, 169, 607],
#              'controller': [663],
#              'conversation': [30],
#              'coordination': [363, 625],
#              'couldn': [456],
#              'count': [179, 342, 359, 425, 489, 670, 671, 702],
#              'counter': [662],
#              'course': [205],
#              'crayon': [240, 490],
#              'creationism': [608],
#              'creator': [573],
#              'crosshair': [27, 260],
#              'crush': [454],
#              'cunt': [537, 537, 612, 672],
#              'curve': [333],
#              'd': [202],
#              'dad': [93, 103, 158, 189, 231, 414, 595, 614],
#              'dating': [35],
#              'day': [21, 137, 411, 439, 472, 534],
#              'daycare': [323],
#              'death': [179, 194, 671],
#              'dense': [635, 637],
#              'depth': [612, 672],
#              'deserve': [556],
#              'design': [589],
#              'dial': [283],
#              'dick': [40, 271, 361, 373],
#              'didn': [623, 662],
#              'didnt': [89],
#              'die': [105, 623],
#              'difference': [157],
#              'difficulty': [104, 135, 352],
#              'disability': [689],
#              'disappointment': [30],
#              'disease': [410],
#              'doesn': [269, 393, 458, 468],
#              'dog': [303, 324, 360],
#              'doin': [126],
#              'dollar': [491, 620],
#              'don': [51, 96, 176, 203, 215, 377, 471, 582, 685, 696],
#              'driver': [137],
#              'drug': [588],
#              'drugstore': [192],
#              'drumkit': [668],
#              'dude': [130],
#              'dumbass': [269],
#              'dumber': [472],
#              'earth': [646],
#              'effort': [714],
#              'ego': [19, 101, 466, 602, 615],
#              'enemy': [93, 103, 415, 539, 606],
#              'enough': [322],
#              'equivalent': [14],
#              'erosion': [238],
#              'ethiopia': [237],
#              'everybody': [220, 307, 401],
#              'everyone': [16, 199, 566, 669],
#              'everything': [47],
#              'evolution': [214, 290, 293, 449, 608],
#              'example': [253, 446],
#              'exception': [327],
#              'excuse': [554, 663],
#              'existance': [242, 645],
#              'existence': [8, 293, 589],
#              'expectancy': [299],
#              'eye': [363, 625],
#              'f4': [305],
#              'face': [167, 228, 436, 647, 683],
#              'factory': [6, 31, 388],
#              'failure': [630],
#              'faith': [236],
#              'family': [220, 280, 401, 476],
#              'fan': [66, 99],
#              'father': [581],
#              'fertilizer': [144],
#              'fight': [115],
#              'figure': [634],
#              'film': [434],
#              'fire': [270, 299, 378, 647],
#              'flamethrower': [341],
#              'flight': [70],
#              'floor': [17],
#              'food': [582, 611],
#              'fork': [647],
#              'fortune': [652],
#              'foundation': [147, 245],
#              'freeway': [469],
#              'fuck': [348],
#              'fucking': [60,
#               87,
#               117,
#               138,
#               197,
#               433,
#               468,
#               481,
#               483,
#               494,
#               511,
#               630,
#               632,
#               633],
#              'fundraiser': [266],
#              'galaxy': [637],
#              'game': [41,
#               82,
#               86,
#               117,
#               128,
#               166,
#               180,
#               182,
#               187,
#               224,
#               236,
#               241,
#               244,
#               287,
#               295,
#               398,
#               424,
#               426,
#               441,
#               487,
#               580,
#               599,
#               628,
#               669,
#               676,
#               714],
#              'garbage': [7, 109, 262],
#              'gay': [506],
#              'gene': [2, 397, 446],
#              'generator': [217, 409],
#              'get': [50],
#              'girl': [679],
#              'girlfriend': [627],
#              'glad': [117],
#              'god': [682],
#              'goddamn': [409],
#              'golf': [130, 379, 513, 628],
#              'gonna': [525],
#              'grave': [596, 617],
#              'gravity': [87],
#              'ground': [87, 289, 656],
#              'gun': [590, 606],
#              'guy': [48, 68, 99, 208, 340],
#              'gym': [586],
#              'hand': [108, 336, 363, 625],
#              'handicap': [130, 665],
#              'hanger': [467],
#              'harder': [89],
#              'head': [26, 30, 200, 562, 637],
#              'heel': [575, 584, 594, 610],
#              'highway': [88, 297, 371],
#              'hit': [277, 331, 447],
#              'hitting': [315],
#              'hobby': [337],
#              'hold': [97],
#              'hole': [100],
#              'home': [586],
#              'hostage': [339],
#              'hour': [406],
#              'house': [712],
#              'humanity': [320],
#              'humor': [412],
#              'humour': [564],
#              'hunger': [201, 294, 308, 391],
#              'i': [46, 65, 65, 137, 462, 462, 491],
#              'idea': [66, 295, 523, 654],
#              'idiot': [259, 654],
#              'ignorance': [457],
#              'im': [525, 525, 595],
#              'imagine': [32, 494],
#              'industry': [548],
#              'inferiority': [464],
#              'inside': [143],
#              'inspiration': [607],
#              'install': [142],
#              'instance': [312],
#              'insult': [383, 417, 638],
#              'intelligence': [8],
#              'internet': [275, 345, 357],
#              'intervention': [583],
#              'isnt': [191],
#              'jealous': [49],
#              'jet': [514],
#              'job': [5, 333, 372, 645],
#              'joke': [51, 176, 203, 215, 281, 471, 645, 650, 654, 700],
#              'jump': [19, 466, 615],
#              'jungler': [254],
#              'keyboard': [],
#              'keys': [24],
#              'kfc': [46],
#              'kick': [361],
#              'kid': [496],
#              'kill': [11, 193, 229, 250, 359, 400],
#              'killcam': [434],
#              'killfeed': [676],
#              'kit': [209],
#              'kitchen': [199],
#              'lag': [184, 213, 291, 416, 440],
#              'laughter': [683],
#              'law': [133],
#              'layer': [455, 455],
#              'letter': [6, 388, 515, 713],
#              'level': [39, 62, 226, 384, 602],
#              'life': [60,
#               102,
#               112,
#               189,
#               234,
#               299,
#               389,
#               399,
#               520,
#               529,
#               569,
#               572,
#               609,
#               630],
#              'lifeguard': [2],
#              'lift': [219],
#              'light': [306],
#              'list': [413, 413],
#              'll': [694],
#              'look': [470, 474, 499],
#              'loser': [618],
#              'lot': [446],
#              'lottery': [397],
#              'luck': [710],
#              'm': [148],
#              'makeup': [143],
#              'malpractice': [251],
#              'man': [44, 262, 316],
#              'map': [12, 68, 436, 541],
#              'marksmanship': [161],
#              'masturbation': [296, 443],
#              'match': [342, 526, 567, 592, 649],
#              'matchmaking': [625],
#              'mattress': [396],
#              'meal': [159],
#              'medicine': [683],
#              'memory': [497],
#              'menu': [257],
#              'millon': [343],
#              'mind': [345, 419],
#              'mine': [18],
#              'minute': [102],
#              'miracle': [342, 599],
#              'mistake': [380],
#              'mode': [249, 271, 286, 352],
#              'mom': [396, 521, 706, 706],
#              'money': [678],
#              'monitor': [34, 106, 278, 460, 641],
#              'month': [232, 632],
#              'morning': [634],
#              'mother': [44, 385, 554, 601, 638, 675, 678, 712],
#              'mouse': [69, 81, 134, 152, 160, 329, 364, 475, 694],
#              'mouth': [28, 49, 110, 146, 174, 395, 505, 565, 655],
#              'need': [437],
#              'nobody': [603],
#              'none': [498, 622],
#              'nothing': [520],
#              'number': [246, 605],
#              'object': [637],
#              'objective': [424, 426, 468, 633],
#              'one': [518],
#              'onion': [455],
#              'opinion': [593],
#              'opposite': [47],
#              'option': [352, 640, 702],
#              'order': [224],
#              'oscar': [389],
#              'outside': [455],
#              'oxygen': [399, 697],
#              'pacifist': [22, 249, 354],
#              'pair': [92],
#              'paper': [39],
#              'park': [571],
#              'participation': [14, 370],
#              'party': [416],
#              'pay': [250],
#              'payload': [442, 494, 511, 699],
#              'penguin': [123],
#              'penny': [486],
#              'person': [30, 98, 341, 457, 459, 487, 590, 613, 661],
#              'perspective': [26, 200],
#              'phone': [529, 569, 688],
#              'piece': [144],
#              'pilot': [681],
#              'ping': [660, 671],
#              'place': [346, 556, 567, 618, 646],
#              'plane': [661],
#              'planet': [635],
#              'plausibility': [293],
#              'play': [42, 177, 393, 432, 520, 695],
#              'player': [41, 213, 567],
#              'playstyle': [354],
#              'please': [104],
#              'plumber': [261],
#              'point': [341, 562],
#              'pole': [591],
#              'policy': [406, 552],
#              'pool': [2, 397, 446],
#              'potato': [15, 20],
#              'power': [224, 272, 282, 315],
#              'practice': [145, 180, 707],
#              'prediction': [295],
#              'pregnancy': [442, 494, 511, 598, 632, 633, 678],
#              'press': [305],
#              'prick': [220, 401],
#              'problem': [382],
#              'process': [61],
#              'profile': [35, 560, 702],
#              'proof': [564],
#              'property': [579],
#              'puberty': [546],
#              'push': [442, 494, 511, 699],
#              'pussy': [576, 666],
#              'question': [544],
#              'queue': [451],
#              'quit': [522],
#              'raisin': [60],
#              'randomize': [573],
#              'range': [341],
#              'rank': [466],
#              'rape': [57],
#              'rate': [76, 299],
#              'ratio': [653],
#              'reaction': [238],
#              'realize': [300],
#              'reason': [2,
#               63,
#               115,
#               231,
#               290,
#               293,
#               309,
#               353,
#               404,
#               473,
#               510,
#               674,
#               682,
#               699],
#              'recoil': [364],
#              'record': [403],
#              'redemption': [433],
#              'reel': [415],
#              'refrigerator': [306],
#              'refund': [406, 428],
#              'regret': [528],
#              'religion': [682],
#              'respawn': [13, 96],
#              'respect': [556],
#              'rest': [259],
#              'retard': [417, 667],
#              'reunion': [476],
#              'right': [111, 335],
#              'rock': [39],
#              'room': [221],
#              'roulette': [710],
#              'round': [100, 278],
#              'router': [292, 688],
#              's': [158, 194, 373, 396, 414, 415, 629, 675],
#              'safer': [346],
#              'saint': [599],
#              'salt': [1, 159, 225, 268, 568, 574, 582, 656],
#              'salty': [113, 156, 162, 264, 322, 485],
#              'sandwich': [138, 197, 624],
#              'school': [161, 590, 709],
#              'score': [18, 194, 196, 379, 500, 513, 604, 628, 660],
#              'scoreboard': [154, 168, 458, 489, 701],
#              'screen': [125, 139, 210, 470, 474, 694],
#              'screencap': [342],
#              'script': [550],
#              'sea': [195],
#              'season': [159],
#              'seawater': [656],
#              'selection': [205, 290],
#              'send': [342],
#              'sense': [412, 528, 564],
#              'sentence': [72, 420, 664],
#              'server': [326],
#              'sex': [648],
#              'shame': [681],
#              'shampoo': [63],
#              'shark': [481],
#              'shit': [28,
#               49,
#               97,
#               110,
#               126,
#               144,
#               146,
#               174,
#               261,
#               360,
#               433,
#               455,
#               505,
#               539],
#              'shittalk': [217],
#              'shitty': [367],
#              'shoe': [321],
#              'shoot': [141, 190],
#              'shot': [491, 620, 694],
#              'shoutout': [118],
#              'side': [295],
#              'similarity': [706],
#              'singleplayer': [394],
#              'sister': [280, 675],
#              'size': [321],
#              'skill': [226, 258, 339, 603, 695],
#              'smarter': [163],
#              'smoking': [520],
#              'sniper': [247, 557],
#              'snowshovel': [362],
#              'sole': [150],
#              'somehow': [307],
#              'someone': [104, 287, 395, 468, 573, 598, 632, 647],
#              'something': [39,
#               80,
#               108,
#               175,
#               177,
#               179,
#               191,
#               194,
#               298,
#               356,
#               364,
#               377,
#               484,
#               583,
#               605,
#               685,
#               696,
#               710,
#               714],
#              'son': [651],
#              'sound': [458],
#              'soup': [78, 163],
#              'speed': [80],
#              'sperm': [343, 348, 396],
#              'spray': [169],
#              'spy': [598],
#              'stairs': [70],
#              'statement': [163],
#              'steam': [227],
#              'sticker': [665],
#              'stormtrooper': [45, 188, 230, 383],
#              'strategy': [9],
#              'stuck': [99],
#              'stupidity': [56],
#              'suck': [706],
#              'suicide': [11, 703],
#              'support': [107, 227, 398, 450, 529, 555, 569, 629],
#              'sure': [191, 342],
#              'system': [288, 625],
#              't': [3,
#               7,
#               30,
#               35,
#               58,
#               87,
#               96,
#               100,
#               105,
#               130,
#               190,
#               204,
#               262,
#               269,
#               307,
#               335,
#               369,
#               377,
#               393,
#               422,
#               442,
#               456,
#               458,
#               468,
#               494,
#               511,
#               582,
#               601,
#               623,
#               633,
#               662,
#               669,
#               685,
#               696],
#              'take': [170, 499],
#              'talk': [67, 404],
#              'tapestry': [117],
#              'team': [55,
#               109,
#               119,
#               157,
#               199,
#               245,
#               305,
#               347,
#               372,
#               387,
#               390,
#               403,
#               415,
#               499,
#               507,
#               539,
#               544,
#               559,
#               571,
#               598,
#               606,
#               611,
#               616,
#               622,
#               629,
#               643,
#               676],
#              'teller': [652],
#              'term': [577],
#              'terrorist': [346],
#              'testament': [523],
#              'thing': [85,
#               111,
#               164,
#               183,
#               192,
#               207,
#               236,
#               328,
#               402,
#               429,
#               480,
#               512,
#               572,
#               592,
#               635],
#              'threat': [302],
#              'till': [151],
#              'time': [4,
#               46,
#               52,
#               64,
#               65,
#               74,
#               105,
#               128,
#               204,
#               206,
#               238,
#               279,
#               283,
#               374,
#               430,
#               445,
#               491,
#               525,
#               538,
#               585,
#               585,
#               596,
#               617,
#               620,
#               649,
#               652],
#              'timer': [13],
#              'today': [367, 652],
#              'toilet': [17],
#              'tool': [212, 600],
#              'track': [560, 662],
#              'trackball': [148],
#              'trade': [571],
#              'trading': [73],
#              'traffic': [432],
#              'traget': [707],
#              'transportation': [271],
#              'trap': [102],
#              'trash': [7, 109, 137, 262],
#              'travel': [458],
#              'tree': [220, 401],
#              'trigger': [52],
#              'trip': [62, 96],
#              'truck': [137],
#              'turn': [127, 335],
#              'tutorial': [33, 48, 202, 233, 448, 619],
#              'type': [341, 459, 567, 590],
#              'typing': [585],
#              'ugliness': [711],
#              'underneath': [455],
#              'universe': [634],
#              'use': [21, 144, 537],
#              'value': [463, 579, 593],
#              'variety': [580],
#              'viagra': [192],
#              'video': [54, 324, 479],
#              'view': [562],
#              'vocabulary': [72, 420, 664],
#              'wait': [58, 151, 187],
#              'wall': [79, 711],
#              'war': [413],
#              'warmth': [612, 672],
#              'wasn': [58],
#              'water': [1, 113, 150, 331, 447, 472, 575, 584, 594, 610],
#              'way': [62,
#               96,
#               193,
#               211,
#               232,
#               237,
#               294,
#               391,
#               458,
#               484,
#               503,
#               576,
#               600,
#               677],
#              'weightlifting': [403],
#              'wheel': [208],
#              'win': [76],
#              'woman': [169],
#              'world': [201, 264, 294, 308, 346, 391, 683],
#              'worry': [307],
#              'year': [211, 237, 527],
#              'yesterday': [411],
#              'yours': [414],
#              'zero': [381],
#              'zipper': [655],
#              'zoo': [545]})

# %%
checkWord = 'aim'
dataTable.ix[  keyDict[ checkWord]  ]['Text']
# Out:
# 17                            With aim like that, I pity whoever has to clean the floor around your toilet
# 35                              i don't know what gets less hits... your aim or your online dating profile
# 188                                                          Even a stormtrooper has a better aim than you
# 223                                          Your aim is so poor Bono is holding a charity concert for it.
# 266                                               Your aim is so poor that people held a fundraiser for it
# 289                                            Your aim is so shit you couldn't hit the ground if you fell
# 296                                         Your aim is proof that excessive masturbation causes blindness
# 331                                    Your aim is so bad you couldn't hit water if you fell out of a boat
# 359                                               Even a common cold has a higher kill count than your aim
# 373                                                 You're lucky your dad's dick had better aim than you.
# 414                               If your dad's aim was as good as yours we wouldn't be talking right now.
# 421                                         I'd call your aim cancer, but at least cancer can kill people.
# 437                            Your aim is so poor, even African countries feel the need to donate to you.
# 451                                      With that aim, I'm impressed you could even hit the queue button.
# 454                                                        Your aim is like your crush, never gonna hit it
# 524                                                             I'd call your aim cancer, but cancer kills
# 530                                                  I'd say your aim is cancer, but cancer actually kills
# 595                             With that poor aim, im surprised your dad figured out where to stick it in
# 687                                          I'd say your aim is cancer, but cancer actually kills people.
# 692                                 With an aim like that, I'm surprised you were able to turn your PC on.
# 707    I think you need more practice with your aim. You can try using the broadside of a barn as a tra...
# Name: Text, dtype: object
